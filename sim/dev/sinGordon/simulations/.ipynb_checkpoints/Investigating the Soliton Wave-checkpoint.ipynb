# %%
import matplotlib.pyplot as plt
import numpy as np
import langanLib
from mpl_toolkits.mplot3d import Axes3D 

# %matplotlib notebook
# %matplotlib notebook


def binMatrix(arr, new_shape):
    shape = (new_shape[0], arr.shape[0] // new_shape[0],
            new_shape[1], arr.shape[1] // new_shape[1])
    return arr.reshape(shape).mean(-1).mean(1)

# %%
# %matplotlib notebook
n = 100
kappa = .1
mu = .01
beta = 2
lnoise = np.sqrt(12./beta)
grid = np.zeros([n,n], order = 'f')
langanLib.langan.init_random_seed()
langanLib.langan.initializegrid(grid)

# %%
plt.imshow(grid.T, origin = 'top', cmap = 'twilight')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
lgrid = []
lham = []
dh = []

n = 100
kappa = 20
mu = 0.01
beta = 5000
lnoise = np.sqrt(12./beta)
langanLib.langan.initializegrid(grid)
ngrid=grid
interations = 10000
plots = 6
div = int(interations/plots)

print(np.sqrt(kappa/mu))
print(div)
for t in np.arange(interations):
    grid = ngrid
    [ngrid,hgrid]=langanLib.langan.update(grid,lnoise,kappa, mu,n)
    if(t%(interations/100)) == 0:
        
        dh.append([t,np.sqrt(np.mean( (ngrid-grid)**2))])
    if (t%div) == 0:
        print('yes')
        lgrid.append(ngrid)
        lham.append(hgrid)
dh = np.array(dh).T
fig,ax = plt.subplots()
ax.loglog(dh[0],dh[1])
# Out:
# 44.721359549995796
# 1666
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# <img src="data:image/png;base64,..." width="640">

# %%
fig,ax = plt.subplots(ncols=2,nrows=3,figsize = (10,20))
for i,a in enumerate(ax.ravel()):
    print(i)
    a.imshow(lgrid[i].T, cmap='twilight')
    a.set_title('interation {}'.format(i*div))
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# 0
# 1
# 2
# 3
# 4
# 5

# %%
len(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-1a2e6ec5f1e3> in <module>()
# ----> 1 len(a)
#
# TypeError: object of type 'AxesSubplot' has no len()

# %%
len(lgrid)
# Out:
# 5

# %%
fig,ax = plt.subplots(ncols=2,nrows=2,figsize = (10,20), subplot_kw={'projection': '3d'})
X,Y = np.indices([n,n])
for i,a in enumerate(ax.ravel()):
    #a.imshow(lham[i].T, vmin = -4*kappa-mu, vmax = 4*kappa, cmap = 'jet')
    Z = binMatrix(lham[i],[20,20])
    X,Y = np.indices(Z.shape)
    a.plot_surface(X, Y, Z.T, linewidth=0, cmap='jet', vmin = -4*kappa-mu, vmax = 4*kappa)
    a.set_title('interation {}'.format(i*div))
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# # The Soliton doesn't work with periodic boundary conditions.

# %% [markdown]
# Now that we have an equilibrium solution, we can feed this back into our model as an initial condition. Then, we will slowly increase the field, from mu=0, to mu=kappa. We will iterate until the hamiltonian differential is converged.
